# %%
"""
Linear Regression

Algoritmo que dado um conjunto de dados
encontra uma linha padrão traçando-os.

Quando vemos uma relação em um diagrama de dispersão, 
podemos usar uma reta para resumir essa relação nos dados. 
Também podemos usar essa reta para fazer previsões a partir dos dados. 
Este processo é chamado de regressão linear.

"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split as tts
import seaborn as sns

# %%
df = pd.read_csv('../CSV Files/student-mat.csv', sep=';')
df

# %%
df_tim = df[['G1', 'G2', 'G3', 'studytime', 'failures', 'absences']]
df_tim

# %%
X = np.array(df_tim.drop(columns=['G3']))
y = np.array(df_tim.G3)

x_train, x_test, y_train, y_test = tts(X, y, test_size=0.1)

model = linear_model.LinearRegression()
model.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print(acc)

# %%
pred = model.predict(x_test)
acertos = 0
for i in range(len(pred)):
    print(f'Valor previsto: {round(pred[i])} Valor correto: {y_test[i]}')
    if round(pred[i]) - y_test[i] <= abs(5):
        acertos += 1
print(f'{acertos} acertos de {len(pred)}')

# %%
df_comparison = pd.DataFrame()
df_comparison["Valores Reais"] = y_test
df_comparison["valores Previstos"] = pred
df_comparison = df_comparison.reset_index(drop=True)

sns.lineplot(data=df_comparison)
plt.show()
